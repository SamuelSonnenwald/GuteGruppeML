# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression

from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFECV, SelectKBest
from sklearn.preprocessing import StandardScaler


maindata = pd.read_csv("https://archive.ics.uci.edu/static/public/2/data.csv")
#maindata.head()

maindata_processed = maindata.copy()

data_target = maindata["income"]

x = data_target
y = maindata_processed

maindata_processed = maindata.drop(columns="income")

label_encoder = preprocessing.LabelEncoder()
data_target = label_encoder.fit_transform(data_target)

encoder = preprocessing.OneHotEncoder()
encoded = pd.DataFrame(encoder.fit_transform(maindata_processed[["workclass","education","marital-status","occupation","relationship","race","sex","native-country"]]).toarray(), columns=encoder.get_feature_names_out(["workclass","education","marital-status","occupation","relationship","race","sex","native-country"]))

maindata_processed = maindata_processed.drop(columns=["workclass","education","marital-status","occupation","relationship","race","sex","native-country"])
maindata_processed = maindata_processed.join(encoded)

data_train, data_test, target_train, target_test = train_test_split(
    maindata_processed, data_target,test_size=0.2, random_state=42, stratify=data_target)

display(data_test)
display(data_train)
logit = LogisticRegression(max_iter = 10000)

print(logit.fit(x,y))

print(logit.score(x,y))
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 30352   62  211408             11             0             0              40
# 1839    45  338105             13             0             0              40
# 8695    23   38251              9             0             0              40
# 31846   29  152461             13             0             0              42
# 33998   42  178074             14             0          1902              40
# ...    ...     ...            ...           ...           ...             ...
# 35711   26  241852              8             0             0              40
# 8765    23  101094             10             0             0              60
# 20612   18  189041              9             0             0              40
# 16710   26  183171              7          1055             0              32
# 9415    26  318644             15             0             0              20
#
#        workclass_?  workclass_Federal-gov  workclass_Local-gov  \
# 30352          0.0                    0.0                  0.0
# 1839           0.0                    0.0                  0.0
# 8695           0.0                    0.0                  0.0
# 31846          0.0                    0.0                  1.0
# 33998          0.0                    1.0                  0.0
# ...            ...                    ...                  ...
# 35711          0.0                    0.0                  0.0
# 8765           0.0                    0.0                  0.0
# 20612          1.0                    0.0                  0.0
# 16710          0.0                    0.0                  0.0
# 9415           0.0                    0.0                  0.0
#
#        workclass_Never-worked  ...  native-country_Puerto-Rico  \
# 30352                     0.0  ...                         0.0
# 1839                      0.0  ...                         0.0
# 8695                      0.0  ...                         0.0
# 31846                     0.0  ...                         0.0
# 33998                     0.0  ...                         0.0
# ...                       ...  ...                         ...
# 35711                     0.0  ...                         0.0
# 8765                      0.0  ...                         0.0
# 20612                     0.0  ...                         0.0
# 16710                     0.0  ...                         0.0
# 9415                      0.0  ...                         0.0
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 30352                      0.0                   0.0                    0.0
# 1839                       0.0                   0.0                    0.0
# 8695                       0.0                   0.0                    0.0
# 31846                      0.0                   0.0                    0.0
# 33998                      0.0                   0.0                    0.0
# ...                        ...                   ...                    ...
# 35711                      0.0                   0.0                    0.0
# 8765                       0.0                   0.0                    0.0
# 20612                      0.0                   0.0                    0.0
# 16710                      0.0                   0.0                    0.0
# 9415                       0.0                   0.0                    0.0
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 30352                      0.0                             0.0
# 1839                       0.0                             0.0
# 8695                       0.0                             0.0
# 31846                      0.0                             0.0
# 33998                      0.0                             0.0
# ...                        ...                             ...
# 35711                      0.0                             0.0
# 8765                       0.0                             0.0
# 20612                      0.0                             0.0
# 16710                      0.0                             0.0
# 9415                       0.0                             0.0
#
#        native-country_United-States  native-country_Vietnam  \
# 30352                           1.0                     0.0
# 1839                            0.0                     0.0
# 8695                            1.0                     0.0
# 31846                           1.0                     0.0
# 33998                           1.0                     0.0
# ...                             ...                     ...
# 35711                           1.0                     0.0
# 8765                            1.0                     0.0
# 20612                           1.0                     0.0
# 16710                           1.0                     0.0
# 9415                            1.0                     0.0
#
#        native-country_Yugoslavia  native-country_nan
# 30352                        0.0                 0.0
# 1839                         0.0                 0.0
# 8695                         0.0                 0.0
# 31846                        0.0                 0.0
# 33998                        0.0                 0.0
# ...                          ...                 ...
# 35711                        0.0                 0.0
# 8765                         0.0                 0.0
# 20612                        0.0                 0.0
# 16710                        0.0                 0.0
# 9415                         0.0                 0.0
#
# [9769 rows x 111 columns]
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 32369   22  174043              9             0             0              50
# 4402    24  399449             13             0             0              40
# 38451   44   79521             13         15024             0              55
# 17233   25  352806              9             0             0              40
# 41292   56   52822             10             0             0              70
# ...    ...     ...            ...           ...           ...             ...
# 29016   44  357814              8             0             0              35
# 11734   65  293385              1             0             0              30
# 31906   48  313925             12             0             0              30
# 36605   44   54271              9             0             0              40
# 6264    38   63509              9             0             0              40
#
#        workclass_?  workclass_Federal-gov  workclass_Local-gov  \
# 32369          0.0                    0.0                  0.0
# 4402           0.0                    0.0                  0.0
# 38451          0.0                    0.0                  0.0
# 17233          0.0                    0.0                  0.0
# 41292          0.0                    0.0                  0.0
# ...            ...                    ...                  ...
# 29016          0.0                    0.0                  1.0
# 11734          1.0                    0.0                  0.0
# 31906          0.0                    0.0                  0.0
# 36605          0.0                    0.0                  0.0
# 6264           0.0                    0.0                  0.0
#
#        workclass_Never-worked  ...  native-country_Puerto-Rico  \
# 32369                     0.0  ...                         0.0
# 4402                      0.0  ...                         0.0
# 38451                     0.0  ...                         0.0
# 17233                     0.0  ...                         0.0
# 41292                     0.0  ...                         0.0
# ...                       ...  ...                         ...
# 29016                     0.0  ...                         0.0
# 11734                     0.0  ...                         0.0
# 31906                     0.0  ...                         0.0
# 36605                     0.0  ...                         0.0
# 6264                      0.0  ...                         0.0
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 32369                      0.0                   0.0                    0.0
# 4402                       0.0                   0.0                    0.0
# 38451                      0.0                   0.0                    0.0
# 17233                      0.0                   0.0                    0.0
# 41292                      0.0                   0.0                    0.0
# ...                        ...                   ...                    ...
# 29016                      0.0                   0.0                    0.0
# 11734                      0.0                   0.0                    0.0
# 31906                      0.0                   0.0                    0.0
# 36605                      0.0                   0.0                    0.0
# 6264                       0.0                   0.0                    0.0
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 32369                      0.0                             0.0
# 4402                       0.0                             0.0
# 38451                      0.0                             0.0
# 17233                      0.0                             0.0
# 41292                      0.0                             0.0
# ...                        ...                             ...
# 29016                      0.0                             0.0
# 11734                      0.0                             0.0
# 31906                      0.0                             0.0
# 36605                      0.0                             0.0
# 6264                       0.0                             0.0
#
#        native-country_United-States  native-country_Vietnam  \
# 32369                           1.0                     0.0
# 4402                            1.0                     0.0
# 38451                           1.0                     0.0
# 17233                           0.0                     0.0
# 41292                           1.0                     0.0
# ...                             ...                     ...
# 29016                           0.0                     0.0
# 11734                           1.0                     0.0
# 31906                           1.0                     0.0
# 36605                           1.0                     0.0
# 6264                            1.0                     0.0
#
#        native-country_Yugoslavia  native-country_nan
# 32369                        0.0                 0.0
# 4402                         0.0                 0.0
# 38451                        0.0                 0.0
# 17233                        0.0                 0.0
# 41292                        0.0                 0.0
# ...                          ...                 ...
# 29016                        0.0                 0.0
# 11734                        0.0                 0.0
# 31906                        0.0                 0.0
# 36605                        0.0                 0.0
# 6264                         0.0                 0.0
#
# [39073 rows x 111 columns]
